# %% [markdown]
# ## Problem: Intersection of Two Linked List

# %% [markdown]
# Given the heads of two singly linked-lists **headA** and **headB**, return the node at which the two lists intersect. If the two linked lists have no intersection at all, return null.<br> ![image.png](attachment:image.png)

# %% [markdown]
# The inputs to the judge are given as follows :
# 1. intersectVal - The value of the node where the intersection occurs. This is 0 if there is no intersected node.
# 2. listA - The first linked list.
# 3. listB - The second linked list.
# 4. skipA - The number of nodes to skip ahead in listA (starting from the head) to get to the intersected node.
# 5. skipB - The number of nodes to skip ahead in listB (starting from the head) to get to the intersected node.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **Input:** intersectVal = 8, listA = [4,1,8,4,5], listB = [5,6,1,8,4,5], skipA = 2, skipB = 3
# <br>**Output:** Intersected at '8'
# <br>**Explanation:** The intersected node's value is 8 (note that this must not be 0 if the two lists intersect).
# From the head of A, it reads as [4,1,8,4,5]. From the head of B, it reads as [5,6,1,8,4,5]. There are 2 nodes before the intersected node in A; There are 3 nodes before the intersected node in B.

# %%
def getIntersectionNode(self, headA, headB):
        """
        :type head1, head1: ListNode
        :rtype: ListNode
        """
        h1 = headA
        h2 = headB
        
        while h1 != h2:
            if not h1:
                h1 = headB
            else:
                h1 = h1.next
            
            if not h2:
                h2 = headA
            else:
                h2 = h2.next
                
        return h1

# %% [markdown]
# so total time complexity is O(m+n) : m is for A and n is for B

# %% [markdown]
# ## Problem : Maximum Twin Sum of Linked List

# %% [markdown]
# In a linked list of size n, where n is even, the ith node (0-indexed) of the linked list is known as the twin of the (n-1-i)th node, if 0 <= i <= (n / 2) - 1.
#
# <br>
# - For example, if n = 4, then node 0 is the twin of node 3, and node 1 is the twin of node 2. These are the only nodes with twins for n = 4.
#
# ![image.png](attachment:image.png)
#
# **Input:** head = [5,4,2,1]
# <br> **Output:** 6
# <br> **Explanation:**
# - Nodes 0 and 1 are the twins of nodes 3 and 2, respectively. All have twin sum = 6.
# - There are no other nodes with twins in the linked list.
# - Thus, the maximum twin sum of the linked list is 6.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def pairSum(self, head: Optional[ListNode]) -> int:
        container = []
        i = head
        while i:
            container.append(i.val)
            i = i.next
        start = 0
        end = len(container)-1
        res = float('-inf')
        while start + 1!= end:
            temp = container[start] + container[end]
            res = max(res, temp)
            start += 1
            end -= 1
        temp = container[start] + container[end]
        res = max(res, temp)
        return res

# %% [markdown]
# ## Swapped every two adjacent

# %%
def swapNodesInPairs(head: ListNode):
    dummyHead = ListNode(0)
    dummyHead.next = head
    p = dummyHead
    while(p.next != None and p.next.next != None):
        # use first to track first node
        first = p
        p = p.next
        first.next = p.next
        
        # use second to track next node of the pair
        second = p.next.next
        p.next.next = p
        p.next = second
    return dummyHead.nesxt

# %%
[, , 4 , 3 ] --> input 

first ,  second --> [1,2,3,4]

first - 1 , second - 2 

dumy head(p) not be equal to null and dummy head . dummy head not equal to null

List A = [1, 2 , 2, 4] , List B = [2.2,4] ---> dangling pointer
